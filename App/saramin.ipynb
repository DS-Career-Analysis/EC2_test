# %%
from urllib.request import Request, urlopen, HTTPError
import re
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.by import By
import pandas as pd
import csv

keyword = ['데이터 사이언티스트', '데이터 애널리스트']
page = 1
front_url = 'https://www.saramin.co.kr/zf_user/search?search_area=main&search_done=y&search_optional_item=n&searchType=search&searchword='
mid_url = '&recruitPage='
back_url = '&recruitSort=relation&recruitPageCount=100&inner_com_type=&company_cd=0%2C1%2C2%2C3%2C4%2C5%2C6%2C7&show_applied=&quick_apply=n&except_read=n&ai_head_hunting=n&mainSearch=y'
url_data = []
company_name = []
position_name = []
post_title = []
company_position = []

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# url, 공고 이름, 기업명을 찾는 크롤링코드
for search_keyword in keyword:
    driver.get(front_url+search_keyword+mid_url+str(page)+back_url)
    ct_result = driver.find_element(By.XPATH, '//*[@id="recruit_info"]/div[1]/span').text
    total_result = re.sub(r'[^0-9]', '', ct_result)
    page_ct = int(int(total_result)/100)

    for pages in range(1, page_ct+2):
        try:
            driver.get(front_url+search_keyword+mid_url+str(pages)+back_url)
            driver.implicitly_wait(time_to_wait=60)

            div_1 = driver.find_elements(By.CLASS_NAME, "job_tit")
            for item in div_1:
                tmp_url = item.find_element(By.TAG_NAME, "a").get_attribute('href')
                url_data.append(tmp_url)
                tmp_title = item.find_element(By.TAG_NAME, "a").text
                post_title.append(tmp_title)

            div_2 = driver.find_elements(By.CLASS_NAME, "corp_name")
            for item in div_2:
                tmp_cn = item.find_element(By.TAG_NAME, "a").text
                company_name.append(tmp_cn)
                position_name.append(search_keyword)

            div_3 = driver.find_elements(By.CLASS_NAME, "job_condition")
            for item in div_3:
                tmp_po = item.find_element(By.TAG_NAME, "a").text
                first_two_letters = tmp_po[:2]
                company_position.append(first_two_letters)

            time.sleep(3)

        except Exception as e:
            pass

driver.close()
print('검색결과 수 : ', len(url_data))
# Out:
# 검색결과 수 :  128

# %%
from urllib.request import Request, urlopen, HTTPError
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.by import By
import pandas as pd
import csv

content = []

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

#기업 주소, 공고내용 전체 크롤링 코드
for url in url_data:
    driver.get(url)
    driver.implicitly_wait(time_to_wait=60)

    # scroll_one
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(1)
    driver.implicitly_wait(3)

    try:
        
        driver.switch_to.frame("iframe_content_0")
        contents = driver.find_element(By.CLASS_NAME, "user_content").text
        content.append(contents)
        
    except:
        content.append('None')
        continue

driver.close()
saramin_df = pd.DataFrame({'Title' : post_title, 'Company' : company_name, 'Content' : content, 'Link' : url_data, 'Location' : company_position, 'label' : position_name})
saramin_df.to_csv("saramin_df.csv", index = False)

# %% [markdown]
# ## 대기업

# %%
from urllib.request import Request, urlopen, HTTPError
import re
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.by import By
import pandas as pd
import csv

keyword = ['데이터 사이언티스트', '데이터 애널리스트']
page = 1
front_url = 'https://www.saramin.co.kr/zf_user/search?search_area=main&search_done=y&search_optional_item=n&searchType=search&searchword='
mid_url = '&recruitPage='
back_url = '&recruitSort=relation&recruitPageCount=100&inner_com_type=&company_cd=0%2C1%2C2%2C3%2C4%2C5%2C6%2C7&company_type=scale001&show_applied=&quick_apply=n&except_read=n&ai_head_hunting=n&mainSearch=y'
url_data = []
company_name = []
position_name = []
post_title = []
company_position = []

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# url, 공고 이름, 기업명을 찾는 크롤링코드
for search_keyword in keyword:
    driver.get(front_url+search_keyword+mid_url+str(page)+back_url)
    ct_result = driver.find_element(By.XPATH, '//*[@id="recruit_info"]/div[1]/span').text
    total_result = re.sub(r'[^0-9]', '', ct_result)
    page_ct = int(int(total_result)/100)

    for pages in range(1, page_ct+2):
        try:
            driver.get(front_url+search_keyword+mid_url+str(pages)+back_url)
            driver.implicitly_wait(time_to_wait=60)

            div_1 = driver.find_elements(By.CLASS_NAME, "job_tit")
            for item in div_1:
                tmp_url = item.find_element(By.TAG_NAME, "a").get_attribute('href')
                url_data.append(tmp_url)
                tmp_title = item.find_element(By.TAG_NAME, "a").text
                post_title.append(tmp_title)

            div_2 = driver.find_elements(By.CLASS_NAME, "corp_name")
            for item in div_2:
                tmp_cn = item.find_element(By.TAG_NAME, "a").text
                company_name.append(tmp_cn)
                position_name.append(search_keyword)

            time.sleep(3)

        except Exception as e:
            pass

driver.close()
print('검색결과 수 : ', len(url_data))
# Out:
# 검색결과 수 :  4

# %%
from urllib.request import Request, urlopen, HTTPError
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.by import By
import pandas as pd
import csv

content = []

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

#기업 주소, 공고내용 전체 크롤링 코드
for url in url_data:
    driver.get(url)
    driver.implicitly_wait(time_to_wait=60)

    # 스크롤을 내리지 않으면 필요한 element가 나타나지 않는 공고가 다수 있어 스크롤을 내리고 크롤링 진행하였습니다.
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(1)
    driver.implicitly_wait(3)

    try:
        address = driver.find_element(By.CLASS_NAME, 'address').text
        company_position.append(address)

    except:
        company_position.append('None')
        pass

    try:
        
        driver.switch_to.frame("iframe_content_0")
        contents = driver.find_element(By.CLASS_NAME, "user_content").text
        content.append(contents)
        
    except:
        content.append('None')
        continue

driver.close()
saramin_df = pd.DataFrame({'회사명' : company_name, '직무' : position_name, '링크' : url_data, '공고내용' : content, '회사주소' : company_position})
saramin_df.to_csv("major_df.csv", index = False)
